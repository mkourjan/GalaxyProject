# %%
# %pylab inline
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
from IPython.html.widgets import interact, interactive, fixed
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import Toomre as Toomre

# %%
Toomre.Generate_Data()

# %%
a = interact(Toomre.Make_Plots,results = fixed(np.load('Toomre_A.npy')), t = (0.1,20.1), dt = fixed(0.0075))

# %%
b = interact(Toomre.Make_Plots,results = fixed(np.load('Toomre_B.npy')),t = (0.1,20.1), dt = fixed(0.0075))
